# %% [markdown]
# # Preliminary

# %% [markdown]
# ## Setup the working environment

# %% [markdown]
# Before you start, ensure to download the ``assets`` folder.
# It has three sub folders
#
# - ``2D_data/``: contain data that will be used in Part I
# - ``images/``: contains two images of CelebaHQ dataset used in Part II
# - ``py_code/``: provides python code to help in both parts
#
# ```
#   assets/
#   ├──── 2D_data/
#   |       └── cloud_points.pt
#   |       └── ...
#   ├──── images/
#   |       └── 00010.jpg
#   |       └── ...
#   ├──── py_code/
#   |    └── diffusion.py
#   |    └── ...
# ```
#
# Make sure to place this folder in same level as the notebook (or python scripts) you will using to work on the two parts.
#
# **Example**
#
# ```
#   ├── assets/
#   ├── part_0.ipynb
# ```
#
# where ``part_0.ipynb`` refer to the current notebook.

# %%
# check that
import os

os.path.isdir("./assets")
# Out:
# True

# %% [markdown]
# ## Test the availability of python packages

# %% [markdown]
# Ensure the all python packages used throughout the practical session are installed.
#
# Running the following cells should not raise any error

# %%
# !pip install numpy torch
# Out:
# Requirement already satisfied: numpy in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (2.3.5)
# Requirement already satisfied: torch in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (2.9.1)
# Requirement already satisfied: filelock in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from torch) (3.6)
# Requirement already satisfied: jinja2 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from jinja2->torch) (3.0.3)

# %%
# check PyTorch is installed
import torch

# %%
# !pip install diffusers
# Out:
# Requirement already satisfied: diffusers in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (0.35.2)
# Requirement already satisfied: importlib_metadata in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from diffusers) (8.7.0)
# Requirement already satisfied: filelock in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from diffusers) (3.20.0)
# Requirement already satisfied: huggingface-hub>=0.34.0 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from diffusers) (1.1.5)
# Requirement already satisfied: numpy in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from diffusers) (2.3.5)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from diffusers) (2025.11.3)
# Requirement already satisfied: requests in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from diffusers) (2.32.5)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from diffusers) (0.7.0)
# Requirement already satisfied: Pillow in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from diffusers) (12.0.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (6.0.3)
# Requirement already satisfied: shellingham in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (4.67.1)
# Requirement already satisfied: typer-slim in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (4.15.0)
# Requirement already satisfied: anyio in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.34.0->diffusers) (4.11.0)
# Requirement already satisfied: certifi in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.34.0->diffusers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.34.0->diffusers) (1.0.9)
# Requirement already satisfied: idna in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.34.0->diffusers) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.34.0->diffusers) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.34.0->diffusers) (1.3.1)
# Requirement already satisfied: zipp>=3.20 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from importlib_metadata->diffusers) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from requests->diffusers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from requests->diffusers) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in /Users/sarasaad/Documents/BDMA /CentraleSupelec/Deep Learning/DiffusionModels/.venv/lib/python3.11/site-packages (from typer-slim->huggingface-hub>=0.34.0->diffusers) (8.3.1)

# %%
# check diffusers
import diffusers

# %%
# !pip install matplotlib tqdm -qqqq

# %%
# check matplotlib
import matplotlib

# %%
# this not mandatory, but is good to have it in order to monitor the progress of loop
import tqdm
